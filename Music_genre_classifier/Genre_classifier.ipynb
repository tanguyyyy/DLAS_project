# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install librosa
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install pydub
# !{sys.executable} -m pip install scikit-learn
# !{sys.executable} -m pip install ipywidgets
# !{sys.executable} -m pip install tqdm
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: librosa in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.10.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (0.3.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.0.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.23.5)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (0.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.2.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (1.10.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from numba>=0.51.0->librosa) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pooch>=1.0->librosa) (2.21.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pooch>=1.0->librosa) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: matplotlib in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pydub in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.25.1)
# Requirement already satisfied: scikit-learn in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: ipywidgets in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.0.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (8.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (6.21.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: packaging in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: pyzmq>=20 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.0.3)
# Requirement already satisfied: psutil in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: nest-asyncio in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.37)
# Requirement already satisfied: colorama in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: backcall in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (305)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.0.0)
# Requirement already satisfied: wcwidth in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: six in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: seaborn in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\benjamin\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
# Import libraries 
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import warnings
warnings.filterwarnings('ignore')
import os
import librosa
import numpy as np
import pandas as pd
import seaborn as sns
from pydub import AudioSegment
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tqdm import tqdm_notebook as tqdm
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
from sklearn.decomposition import PCA


plt.rcParams['figure.figsize'] = [12, 6]

# %%
"""
    - Main Functionalities for Analysing audio files 
"""

def load_file(audio_path, sr=None):
    """ It Loads a audio file 
        returns a signal x and the sample rate sr."""
    x, sr = librosa.load(audio_path, sr=sr)
    return x, sr


def compute_mfccs(x, sr, n_mfcc=20):
    """It computes the Mel Cepstral Coefficients"""
    mfccs = librosa.feature.mfcc(y=x, sr=sr, n_mfcc=n_mfcc)
    return mfccs


def compute_zero_crossing_rate(x, frame_length=2048, hop_length=512):
    """It computes the Zero-Crossing Rate feature"""
    zcrs = librosa.feature.zero_crossing_rate(x, frame_length=frame_length,
                                              hop_length=hop_length)
    return zcrs


def compute_chromagram(x, sr, n_chroma=12, n_octaves=7, hop_length=512):
    """It computes the Chromagram representation."""
    chromagram = librosa.feature.chroma_cqt(x, sr=sr, n_chroma=n_chroma, 
                                            n_octaves=n_octaves, hop_length=hop_length)
    return chromagram


def get_pitches():
    pitches = ["A", "A#", "B", "C", "C#", "D", "D#", "E","F", "F#" ,"G", "G#"]
    return pitches


def get_dictionary_from_numpy(x, N, name="chroma"):
    """It generates a dictionary of features given a signal x,
    N chunks and the name of the feature."""
    
    stats_names = ["_mean", "_std", "_median", "_min", "_max"]
    if name == "chroma":
        pitches = get_pitches()
        feat_keys = [name + "_" + pitches[j] + z + "_" + str(i+1)  for i in range(N) for j in range(x.shape[1]) for z in stats_names]
    else:
        feat_keys = [name + "_" + str(j+1) + z + "_" + str(i+1)  for i in range(N) for j in range(x.shape[1]) for z in stats_names]
    
    # Flatten 
    x_flatten = x.flatten().tolist()
    feature_dictionary = dict(zip(feat_keys, x_flatten))
    return feature_dictionary    


def compute_temporal_stat(x, N, axis=1, stat=np.mean):
    """Given a signal x, a number of chunks N and a statistical function, 
    it splits the array into N chunks and compute the statistics regarding
    stat parameter"""
    x_split = np.array_split(x, N, axis=axis)
    x_temp_stat = [stat(x_s, axis=axis) for x_s in x_split]
    x_temp_stat = np.array(x_temp_stat)
    x_temp_stat = x_temp_stat[:,:,np.newaxis]
    return x_temp_stat


def get_feature_matrix(x, N, axis=1):
    """Automatically compute all the statistics for the N chunks of the signal x."""
    stats = [np.mean, np.std, np.median, np.min, np.max]
    x_stat_n = np.array([])
    for ii, stat in enumerate(stats):
        x_stat_temp = compute_temporal_stat(x,N, axis, stat) # N x m
        
        if ii == 0:
            x_stat_n = x_stat_temp
        else:
            x_stat_n = np.concatenate([x_stat_n, x_stat_temp], axis=2)
        
    return x_stat_n


def compute_audio_features(x_chroma=None, x_mfcc=None, x_zcrs=None, N=3):
    if x_chroma is not None:
        # Chromagram feature matrix
        chrom_feature_matrix = get_feature_matrix(x_chroma, N)
    else:
        chrom_feature_matrix = None
    
    if x_mfcc is not None:
        # MFCC feature matrix
        mfcc_feature_matrix = get_feature_matrix(x_mfcc, N)
    else:
        mfcc_feature_matrix = None
    
    if x_zcrs is not None:
        # Zero-Crossing Rate
        zcrs_feature_matrix = get_feature_matrix(x_zcrs, N)
    else:
        zcrs_feature_matrix = None
    return (chrom_feature_matrix, mfcc_feature_matrix, zcrs_feature_matrix)


def get_audio_feature_dict(chrom_feature_matrix=None, mfcc_feature_matrix=None,
                           zcrs_feature_matrix=None, N=3):
    """
        Given a set of features, it generates a dictionary where all the features are included.
    """
    feature_dictionary = {}
    if chrom_feature_matrix is not None:
        feature_dictionary.update(get_dictionary_from_numpy(chrom_feature_matrix, N, name="chroma"))
    if mfcc_feature_matrix is not None:
        feature_dictionary.update(get_dictionary_from_numpy(mfcc_feature_matrix, N, name="mfcc"))
    if zcrs_feature_matrix is not None:
        feature_dictionary.update(get_dictionary_from_numpy(zcrs_feature_matrix, N, name="zcrs"))
    return feature_dictionary


def process_audio_file_batch(parent_dir, audio_files, sr=None, n_fft=2048, hop_length=512,
                             n_mfcc=20, n_chroma=12, n_octaves=7, chunks=3, chroma=True,
                             mfcc=True, zcrs=True):
    """
        It receives a list of audio files and for each audio it computs the different audio features. 
        It returns a list of features corresponding to each audio file.
    """
    data_features = []
    
    with tqdm(total=len(audio_files)) as pbar:
        for i, audio in enumerate(audio_files):
            pbar.update(1)
            # Generate full path
            audio_path = os.path.join(parent_dir, audio)

            # Load file
            x, sr = load_file(audio_path, sr=sr)
            
            if mfcc:
                # Compute MFCC
                x_mfcc = compute_mfccs(x, sr=sr, n_mfcc=n_mfcc)
            else:
                x_mfcc = None
            
            if chroma:
                # Compute Chromagram
                x_chroma = compute_chromagram(x, sr=sr, n_chroma=n_chroma, n_octaves=n_octaves,
                                              hop_length=hop_length)
            else:
                x_chroma = None
            
            if zcrs:
                # Compute Zero-Crossing Rate
                x_zcrs = compute_zero_crossing_rate(x, frame_length=n_fft, hop_length=hop_length)
            else:
                x_zcrs = None
            
            
            # Compute audio features
            chrom_feature_matrix, mfcc_feature_matrix, zcrs_feature_matrix = compute_audio_features(x_chroma,
                                                                                                    x_mfcc,
                                                                                                    x_zcrs,
                                                                                                    N=chunks)

            # Generate feature dictionary
            feature_dictionary = get_audio_feature_dict(chrom_feature_matrix, mfcc_feature_matrix,
                                                        zcrs_feature_matrix, N=chunks)

            # Concatenate data
            data_features.append(feature_dictionary)
    return data_features


def generate_data(parent_dir, folders, sr, n_fft, hop_length, n_mfcc, n_chroma, n_octaves, chunks,
                 apply_chroma=True, apply_mfcc=True, apply_zcrs=True):
    """
        Given a set of folders where the audio files are included, it processes them and generates 
        a solid feature vector.
    """
    labels = []
    audio_full_paths = []
    # Go Through the folders
    for folder in os.listdir(parent_dir):
        if (folder in folders) and (folder!='hip-hop'):                
            print("Retrieving data from folder {}".format(folder))
            # Get audio files
            new_files = os.listdir(os.path.join(parent_dir, folder))
            audio_full_paths += [os.path.join(os.path.join(parent_dir, folder), jj) for jj in new_files]
            labels += [folder for i in range(len(new_files))]
    print(parent_dir)
    print(audio_full_paths[:2])
    print(len(audio_full_paths))
    
    # Process data
    data_features = process_audio_file_batch('', audio_full_paths, sr, n_fft,
                                             hop_length, n_mfcc, n_chroma, n_octaves, chunks,
                                             chroma=apply_chroma, mfcc=apply_mfcc, zcrs=apply_zcrs)
    return data_features, labels, audio_full_paths


def get_dataframe_from_data(data_features, audio_full_paths, labels, save_locally=False, filepath=None):
    """Given a dictionary of features, it generates a Pandas DataFrame."""
    df = pd.DataFrame(data_features)
    df["genre"] = labels 
    df["filepath"] = audio_full_paths
    if save_locally:
        df.to_csv(filepath)
    return df

# %%
data_path1="music_dataset_part1\\audio_files"
data_path2="music_dataset_part2\\audio_files"
folder1='edm'

# %%
chunks=3 # Number of chunks of the audio file
sr=44100 # Sample rate
n_mfcc=20 # Number of Mel cepstral coefficients
n_fft=2048 # Number of FFT points
hop_length=int(n_fft/4) # Number of Overlapped samples
n_chroma=12 # Number of pitches
n_octaves=7 #Number of octaves
save_locally=True # save data locally
apply_chroma=False # apply chromagram representation
apply_mfcc=True # apply MFCC representation
apply_zcrs=True # apply zcrs representation

# %%
data_features1, labels1, audio_full_paths1 = generate_data(parent_dir=data_path1, folders=['edm', 'hip-hop','jazz','rock'], sr=sr, n_fft=n_fft, hop_length=int(n_fft/4), n_mfcc=n_mfcc, n_chroma=n_chroma, n_octaves=n_octaves, chunks=chunks,
                 apply_chroma=apply_chroma, apply_mfcc=apply_mfcc, apply_zcrs=apply_zcrs)
# Out:
# Retrieving data from folder edm
# Retrieving data from folder jazz
# Retrieving data from folder rock
# music_dataset_part1\audio_files
# ['music_dataset_part1\\audio_files\\edm\\.ipynb_checkpoints', 'music_dataset_part1\\audio_files\\edm\\03nmxeZEIZuKvgnXdz88mT.mp3']
# 200
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'music_dataset_part1\\audio_files\\edm\\.ipynb_checkpoints': System error.
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_features1, labels1, audio_full_paths1 = generate_data(parent_dir=data_path1, folders=['edm', 'hip-hop','jazz','rock'], sr=sr, n_fft=n_fft, hop_length=int(n_fft/4), n_mfcc=n_mfcc, n_chroma=n_chroma, n_octaves=n_octaves, chunks=chunks,
#       2                  apply_chroma=apply_chroma, apply_mfcc=apply_mfcc, apply_zcrs=apply_zcrs)
#
# Cell In[4], line 190, in generate_data(parent_dir, folders, sr, n_fft, hop_length, n_mfcc, n_chroma, n_octaves, chunks, apply_chroma, apply_mfcc, apply_zcrs)
#     187 print(len(audio_full_paths))
#     189 # Process data
# --> 190 data_features = process_audio_file_batch('', audio_full_paths, sr, n_fft,
#     191                                          hop_length, n_mfcc, n_chroma, n_octaves, chunks,
#     192                                          chroma=apply_chroma, mfcc=apply_mfcc, zcrs=apply_zcrs)
#     193 return data_features, labels, audio_full_paths
#
# Cell In[4], line 132, in process_audio_file_batch(parent_dir, audio_files, sr, n_fft, hop_length, n_mfcc, n_chroma, n_octaves, chunks, chroma, mfcc, zcrs)
#     129 audio_path = os.path.join(parent_dir, audio)
#     131 # Load file
# --> 132 x, sr = load_file(audio_path, sr=sr)
#     134 if mfcc:
#     135     # Compute MFCC
#     136     x_mfcc = compute_mfccs(x, sr=sr, n_mfcc=n_mfcc)
#
# Cell In[4], line 8, in load_file(audio_path, sr)
#       5 def load_file(audio_path, sr=None):
#       6     """ It Loads a audio file
#       7         returns a signal x and the sample rate sr."""
# ----> 8     x, sr = librosa.load(audio_path, sr=sr)
#       9     return x, sr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:60, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      51 """Warn the user, and then proceed."""
#      52 warnings.warn(
#      53     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      54     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      58     stacklevel=3,  # Would be 2, but the decorator adds a level
#      59 )
# ---> 60 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\audio.py:241, in __audioread_load(path, offset, duration, dtype)
#     238     reader = path
#     239 else:
#     240     # If the input was not an audioread object, try to open it
# --> 241     reader = audioread.audio_open(path)
#     243 with reader as input_file:
#     244     sr_native = input_file.samplerate
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\audioread\__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\audioread\rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# PermissionError: [Errno 13] Permission denied: 'music_dataset_part1\\audio_files\\edm\\.ipynb_checkpoints'

# %%
#let's make it a dataset now
df_audios = pd.DataFrame(data=data_features1)

# %%
df_audios['label'] = labels1
df_audios['path'] = audio_full_paths1
df_audios.head()
# Out:
#    mfcc_1_mean_1  mfcc_1_std_1  mfcc_1_median_1  mfcc_1_min_1  mfcc_1_max_1  \
# 0     -51.725040     36.968002       -51.594624   -159.173386     30.148195
# 1     -65.397697     35.161774       -66.009445   -165.860092     32.887779
# 2     -58.372334     27.371698       -57.319206   -210.204498     21.280075
# 3     -84.450386     45.985455       -79.961288   -230.651520     38.036293
# 4     -74.631905     56.134987       -70.735184   -308.824493     31.577541
#
#    mfcc_2_mean_1  mfcc_2_std_1  mfcc_2_median_1  mfcc_2_min_1  mfcc_2_max_1  \
# 0     117.064514     25.855074       111.552765     69.914009    191.043732
# 1     127.540009     21.831797       126.908455     75.148300    210.059143
# 2     128.934586     13.924896       126.979568     87.889809    177.037872
# 3     138.263046     23.019567       138.813553     61.430801    192.606842
# 4     138.344818     22.805267       138.826492     62.536049    192.788910
#
#    ...  zcrs_1_median_2  zcrs_1_min_2  zcrs_1_max_2  zcrs_1_mean_3  \
# 0  ...         0.028809      0.001465      0.197754       0.024488
# 1  ...         0.043457      0.005859      0.178711       0.069806
# 2  ...         0.069336      0.013184      0.143555       0.054915
# 3  ...         0.049805      0.002441      0.191895       0.042981
# 4  ...         0.063477      0.002930      0.194824       0.076392
#
#    zcrs_1_std_3  zcrs_1_median_3  zcrs_1_min_3  zcrs_1_max_3  label  \
# 0      0.024057         0.015137      0.001465      0.096680    edm
# 1      0.034919         0.063477      0.011719      0.209473    edm
# 2      0.034011         0.044434      0.006348      0.160645    edm
# 3      0.025546         0.036133      0.001953      0.152344    edm
# 4      0.046560         0.067383      0.009766      0.318359    edm
#
#                                                 path
# 0  music_dataset_part1\audio_files\edm\02RDuI6zo3...
# 1  music_dataset_part1\audio_files\edm\03nmxeZEIZ...
# 2  music_dataset_part1\audio_files\edm\05DQBenN58...
# 3  music_dataset_part1\audio_files\edm\0757375sae...
# 4  music_dataset_part1\audio_files\edm\07uAmmU5pe...
#
# [5 rows x 317 columns]

# %% [markdown]
# Now, we want to classify some musics. SO let's use for exemple a machine learning algorithm such as a random forest and see if ti works well

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X = df_audios.drop(["label", "path"], axis=1)
y = df_audios["label"]

#split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

rf = RandomForestClassifier(n_estimators=250, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

#some accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8

# %% [markdown]
# With this algorithm, I obtain a maximum accuracy of about 80%, no matter how many trees I use for the classification. Let's make a bigger dataset to see if I have better results.

# %%
#do the same for the second folder
#here I had an issue with the folders given so I created new ones
data_features2, labels2, audio_full_paths2 = generate_data(parent_dir=data_path2, folders=['edm', 'hip-hop','jazz','rock'], sr=sr, n_fft=n_fft, hop_length=int(n_fft/4), n_mfcc=n_mfcc, n_chroma=n_chroma, n_octaves=n_octaves, chunks=chunks,
                 apply_chroma=apply_chroma, apply_mfcc=apply_mfcc, apply_zcrs=apply_zcrs)
# Out:
# Retrieving data from folder edm
# Retrieving data from folder jazz
# Retrieving data from folder rock
# music_dataset_part2\audio_files
# ['music_dataset_part2\\audio_files\\edm\\02RDuI6zo3Y0dFhxA0iKIx.mp3', 'music_dataset_part2\\audio_files\\jazz\\082zyi189u5lRp2gPkE8Lb.mp3']
# 129
#   0%|          | 0/129 [00:00<?, ?it/s]
# music_dataset_part2\audio_files\edm\02RDuI6zo3Y0dFhxA0iKIx.mp3
# music_dataset_part2\audio_files\jazz\082zyi189u5lRp2gPkE8Lb.mp3
# music_dataset_part2\audio_files\jazz\0MOXs5rKfhXY7TooT6iiiP.mp3
# music_dataset_part2\audio_files\jazz\0sGFsWPYyhN4X9LKT1EiOv.mp3
# music_dataset_part2\audio_files\jazz\0T38cI9uIhptfZPlf1El09.mp3
# music_dataset_part2\audio_files\jazz\0Ya7lMXJGmETT1G3bW0uX2.mp3
# music_dataset_part2\audio_files\jazz\0zIqs8nFS5eHLgL0ZprFuP.mp3
# music_dataset_part2\audio_files\jazz\14aFuIi1l2arBrZfBv9fBP.mp3
# music_dataset_part2\audio_files\jazz\1axzRYUUASTfN4OOtrjfQd.mp3
# music_dataset_part2\audio_files\jazz\1qKVWhOUXHlm8baMCOsANy.mp3
# music_dataset_part2\audio_files\jazz\1XrEY8nz2P4L9rVoq9MdXs.mp3
# music_dataset_part2\audio_files\jazz\1y0FhVFVZ2eG82sn0M7H7v.mp3
# music_dataset_part2\audio_files\jazz\21anQnN5XQjhsVoyHkwoVo.mp3
# music_dataset_part2\audio_files\jazz\25cJePcRAgKUKtjH8Wm1MQ.mp3
# music_dataset_part2\audio_files\jazz\29dFStdDNJHdgGPhwyKdbB.mp3
# music_dataset_part2\audio_files\jazz\2BjX0EYypxakiidBW18QmC.mp3
# music_dataset_part2\audio_files\jazz\2cmvEeYY8YPEMOjqwM32ba.mp3
# music_dataset_part2\audio_files\jazz\2crI4VDWhG7m66Bc2afjJw.mp3
# music_dataset_part2\audio_files\jazz\2edcrXwukRbhYa5NuM6MT1.mp3
# music_dataset_part2\audio_files\jazz\2HnkMywsGGmX7alLfLVeqH.mp3
# music_dataset_part2\audio_files\jazz\2muiX4tWrBQP8lqyntgKaB.mp3
# music_dataset_part2\audio_files\jazz\2sno8z2lfzKUrBzdDL1Zpq.mp3
# music_dataset_part2\audio_files\jazz\2sZ1zWeLaquu9tx8IUMuh7.mp3
# music_dataset_part2\audio_files\jazz\2zuCel4NqWnLH28iUQemw1.mp3
# music_dataset_part2\audio_files\jazz\3J10F4lCEb7vdStCZN27z6.mp3
# music_dataset_part2\audio_files\jazz\3MhWFpRMVEyZ9QXGIb5RJK.mp3
# music_dataset_part2\audio_files\jazz\3odLwNmrGr91br8fhtrP1v.mp3
# music_dataset_part2\audio_files\jazz\3ONcanYtZHMVcgqPDAsVHd.mp3
# music_dataset_part2\audio_files\jazz\3Tr4rNbK1hSMS9hlKwgy1l.mp3
# music_dataset_part2\audio_files\jazz\3wPZVnOScmpbn6JkWJxi3S.mp3
# music_dataset_part2\audio_files\jazz\491rM2JN8KvmV6p0oDDuJT.mp3
# music_dataset_part2\audio_files\jazz\499pC27JxKGMh6mYyuRmlT.mp3
# music_dataset_part2\audio_files\jazz\4AxT7oW02TqO772n6SGrfh.mp3
# music_dataset_part2\audio_files\jazz\4cG4S3LHdqibrEXgj87ZNx.mp3
# music_dataset_part2\audio_files\jazz\4IhzWCGC7Rqx7F5yNnxshu.mp3
# music_dataset_part2\audio_files\jazz\4JHItqtk4k5wv207UO1D66.mp3
# music_dataset_part2\audio_files\jazz\4LIw2QRvZWvtV48O92yfKu.mp3
# music_dataset_part2\audio_files\jazz\4OwHfJGfIGluHa3pi7nwlM.mp3
# music_dataset_part2\audio_files\jazz\4rf8E6pZ30cTzysT0tlLeX.mp3
# music_dataset_part2\audio_files\jazz\4z6d79RAbC5q0VAqPQas8W.mp3
# music_dataset_part2\audio_files\jazz\50ma4LjaP5XDL1BsHrZ1D9.mp3
# music_dataset_part2\audio_files\jazz\5Bl1TC8Y1qh3ui6fGSWL5a.mp3
# music_dataset_part2\audio_files\jazz\5fhLDCuNimt2zvkiFxOAbU.mp3
# music_dataset_part2\audio_files\jazz\5FpmRoCduqD28smrRs6mdl.mp3
# music_dataset_part2\audio_files\jazz\5hczVgr3jA5rs9F72O66Ul.mp3
# music_dataset_part2\audio_files\jazz\5ltdjMGizJoqS5x7rZzij2.mp3
# music_dataset_part2\audio_files\jazz\5nrpIB2dVUvhRUs5R9YJ3W.mp3
# music_dataset_part2\audio_files\jazz\5RzDUxNC7hKjr8eTEX8n6b.mp3
# music_dataset_part2\audio_files\jazz\5y3KtLOAPHMhb58BFfrpnF.mp3
# music_dataset_part2\audio_files\jazz\5zpqkOpg31ksUdhuqJ9CQU.mp3
# music_dataset_part2\audio_files\jazz\6bqNdzv1KHd5C7ae0YbV7r.mp3
# music_dataset_part2\audio_files\jazz\6mXID0DbyA7qBZVLPZ1yXg.mp3
# music_dataset_part2\audio_files\jazz\6NpwgYdHNNpq81GnpJNx3Y.mp3
# music_dataset_part2\audio_files\jazz\6qVb2aSxdRwaZrPxugkBou.mp3
# music_dataset_part2\audio_files\jazz\6RsdHCcaWpatuOxqsIbBh6.mp3
# music_dataset_part2\audio_files\jazz\6UFlo3RmCOhIMXDQvpivFf.mp3
# music_dataset_part2\audio_files\jazz\6YKYdsX76JCq5CkIy8eON4.mp3
# music_dataset_part2\audio_files\jazz\70S7sASwrZH3Fass66MKqJ.mp3
# music_dataset_part2\audio_files\jazz\75pv3HGn1sYdbUxERJxUlH.mp3
# music_dataset_part2\audio_files\jazz\76Bk0cDFzg1ljHQpY0SUqV.mp3
# music_dataset_part2\audio_files\jazz\79fmhV6NAraE4Xz3MIXnN4.mp3
# music_dataset_part2\audio_files\jazz\7hPTKT0j7mEn9lBKerFtit.mp3
# music_dataset_part2\audio_files\jazz\7mmXkxpwxKydQbhB2fqqXv.mp3
# music_dataset_part2\audio_files\jazz\7tO5SJLzk1p0KuPaoWI8cx.mp3
# music_dataset_part2\audio_files\jazz\7u38kj1yGDoExUnP6gxxor.mp3
# music_dataset_part2\audio_files\rock\0BRHnOFm6sjxN1i9LJrUDu.mp3
# music_dataset_part2\audio_files\rock\0gaXhpsDfErFWIXzY2XkP0.mp3
# music_dataset_part2\audio_files\rock\0J69x3mqm7U6tBPKsjpsWR.mp3
# music_dataset_part2\audio_files\rock\0kO3njY9N1Rxgv27Ha1lLh.mp3
# music_dataset_part2\audio_files\rock\0OsXnShB0J87QppZHxgjIA.mp3
# music_dataset_part2\audio_files\rock\10Nmj3JCNoMeBQ87uw5j8k.mp3
# music_dataset_part2\audio_files\rock\18lR4BzEs7e3qzc0KVkTpU.mp3
# music_dataset_part2\audio_files\rock\1DnwBj6meWZOzYpsY9fOCa.mp3
# music_dataset_part2\audio_files\rock\1f2V8U1BiWaC9aJWmpOARe.mp3
# music_dataset_part2\audio_files\rock\1H5a6C6jqWN6XQI0Unq7W3.mp3
# music_dataset_part2\audio_files\rock\1LbwMX3159t6QxG3u7DRWe.mp3
# music_dataset_part2\audio_files\rock\1Tv2bC3B9fCTNWP588Hwfj.mp3
# music_dataset_part2\audio_files\rock\1zGEScj98f6OcUpNAOhD2z.mp3
# music_dataset_part2\audio_files\rock\2DrFBNqxtpyvFlG3qMZiya.mp3
# music_dataset_part2\audio_files\rock\2k3IohY9s4B3uxA0tehRjb.mp3
# music_dataset_part2\audio_files\rock\2Wg6jxfc5JhQ7afc2kUFHP.mp3
# music_dataset_part2\audio_files\rock\305WCRhhS10XUcH6AEwZk6.mp3
# music_dataset_part2\audio_files\rock\3C2KzYNrujsAUlzfsAedxV.mp3
# music_dataset_part2\audio_files\rock\3hQe0kHP3mzbHiiN37WGfv.mp3
# music_dataset_part2\audio_files\rock\3l9CW99AHtExIRV4hW2N5m.mp3
# music_dataset_part2\audio_files\rock\3MvxoYs3x5EGIC98q62qhC.mp3
# music_dataset_part2\audio_files\rock\3NS21eAHLLPyfm1NffjnFc.mp3
# music_dataset_part2\audio_files\rock\3nZqrK7QFftU8Kjnr0qjWN.mp3
# music_dataset_part2\audio_files\rock\3Qmos1rUz0txhLKe2lFCLE.mp3
# music_dataset_part2\audio_files\rock\3R3TxklaHKscK12Xo6ytAQ.mp3
# music_dataset_part2\audio_files\rock\3tSmXSxaAnU1EPGKa6NytH.mp3
# music_dataset_part2\audio_files\rock\3Wc9Uk2dEIqqoT1kZKRqO6.mp3
# music_dataset_part2\audio_files\rock\3YuaBvuZqcwN3CEAyyoaei.mp3
# music_dataset_part2\audio_files\rock\3ZOEytgrvLwQaqXreDs2Jx.mp3
# music_dataset_part2\audio_files\rock\40rvBMQizxkIqnjPdEWY1v.mp3
# music_dataset_part2\audio_files\rock\45faYLH7bE4vtHFbbWNaM9.mp3
# music_dataset_part2\audio_files\rock\4bPQs0PHn4xbipzdPfn6du.mp3
# music_dataset_part2\audio_files\rock\4nA5tqss7agxUk3o1IgrnM.mp3
# music_dataset_part2\audio_files\rock\4nUM7pGcTUK2pY1d2LybrT.mp3
# music_dataset_part2\audio_files\rock\4OenRPTF6LdFFUKcAokeGL.mp3
# music_dataset_part2\audio_files\rock\4STtE8vtSXM17vVqp4KQhK.mp3
# music_dataset_part2\audio_files\rock\4t7xcd1KMNzxKMIsDQolCz.mp3
# music_dataset_part2\audio_files\rock\4yhDKm4lUouVArVOvQj4HL.mp3
# music_dataset_part2\audio_files\rock\4ZsRa4Oz9yb6eqzbGVmd0V.mp3
# music_dataset_part2\audio_files\rock\5dTHtzHFPyi8TlTtzoz1J9.mp3
# music_dataset_part2\audio_files\rock\5fZtRNrp6xHHEd5nFMGzN9.mp3
# music_dataset_part2\audio_files\rock\5GorCbAP4aL0EJ16frG2hd.mp3
# music_dataset_part2\audio_files\rock\5hG3Xy20wHbzGil4eqCIgR.mp3
# music_dataset_part2\audio_files\rock\5NeIONQWJ25uPylJBJiO4c.mp3
# music_dataset_part2\audio_files\rock\5oavHr1Xk65ehSo43KPe5f.mp3
# music_dataset_part2\audio_files\rock\5OuYZMb9jcIiyPAXTFb1uz.mp3
# music_dataset_part2\audio_files\rock\5souisTu8linx6zKNsTVos.mp3
# music_dataset_part2\audio_files\rock\5vfjUAhefN7IjHbTvVCT4Z.mp3
# music_dataset_part2\audio_files\rock\5wQnmLuC1W7ATsArWACrgW.mp3
# music_dataset_part2\audio_files\rock\69ZTLfuCsYBLA6gY7YUC7d.mp3
# music_dataset_part2\audio_files\rock\6BEPqCmZGNMcTY2BgyEDCP.mp3
# music_dataset_part2\audio_files\rock\6nTiIhLmQ3FWhvrGafw2zj.mp3
# music_dataset_part2\audio_files\rock\6nzpzKqZuZbNLFor98P1fL.mp3
# music_dataset_part2\audio_files\rock\6rUp7v3l8yC4TKxAAR5Bmx.mp3
# music_dataset_part2\audio_files\rock\71H2SB2sNLUuGvZ8iV02cT.mp3
# music_dataset_part2\audio_files\rock\72NWqy2tK4RSd9PwH9RXbC.mp3
# music_dataset_part2\audio_files\rock\731BpBsbqtNLC5RREuOJrv.mp3
# music_dataset_part2\audio_files\rock\7CYwpzjYx7TjguC3ukmkIU.mp3
# music_dataset_part2\audio_files\rock\7g1ox21Mf43eCuxG5KhICI.mp3
# music_dataset_part2\audio_files\rock\7i6r9KotUPQg3ozKKgEPIN.mp3
# music_dataset_part2\audio_files\rock\7j31rVgGX9Q2blT92VBEA0.mp3
# music_dataset_part2\audio_files\rock\7JFFMRhoNa0UCYeasEh4YF.mp3
# music_dataset_part2\audio_files\rock\7kwiwQhWRBSP1PJv4ZFJUK.mp3
# music_dataset_part2\audio_files\rock\7lRlq939cDG4SzWOF4VAnd.mp3

# %%
df_audios2 = pd.DataFrame(data=data_features2)
df_audios2['label'] = labels2
df_audios2['path'] = audio_full_paths2
df_audios2.head()
# Out:
#    mfcc_1_mean_1  mfcc_1_std_1  mfcc_1_median_1  mfcc_1_min_1  mfcc_1_max_1  \
# 0     -51.725040     36.968002       -51.594624   -159.173386     30.148195
# 1    -427.757599     41.782753      -435.005585   -538.387329   -271.668457
# 2    -100.432243     29.886513       -97.466415   -173.598251    -21.343803
# 3     -81.861382     33.203468       -82.986160   -170.002472     -5.552082
# 4    -243.069611     47.051453      -238.296524   -348.078827   -135.520462
#
#    mfcc_2_mean_1  mfcc_2_std_1  mfcc_2_median_1  mfcc_2_min_1  mfcc_2_max_1  \
# 0     117.064514     25.855074       111.552765     69.914009    191.043732
# 1     181.456757     23.384613       182.835114     96.523819    252.730118
# 2     154.977127     12.587070       155.194702     87.483780    192.715637
# 3     160.103210     23.012730       162.865295     98.371590    211.797333
# 4     172.242310     21.763165       176.134064     91.211510    213.234680
#
#    ...  zcrs_1_median_2  zcrs_1_min_2  zcrs_1_max_2  zcrs_1_mean_3  \
# 0  ...         0.028809      0.001465      0.197754       0.024488
# 1  ...         0.019531      0.002930      0.090332       0.019532
# 2  ...         0.044922      0.011719      0.216797       0.045955
# 3  ...         0.045410      0.008301      0.137207       0.042587
# 4  ...         0.038086      0.013672      0.130859       0.038776
#
#    zcrs_1_std_3  zcrs_1_median_3  zcrs_1_min_3  zcrs_1_max_3  label  \
# 0      0.024057         0.015137      0.001465      0.096680    edm
# 1      0.009930         0.017578      0.004883      0.106934   jazz
# 2      0.026346         0.041016      0.006348      0.161133   jazz
# 3      0.019654         0.040527      0.003418      0.116211   jazz
# 4      0.019150         0.033203      0.013184      0.124023   jazz
#
#                                                 path
# 0  music_dataset_part2\audio_files\edm\02RDuI6zo3...
# 1  music_dataset_part2\audio_files\jazz\082zyi189...
# 2  music_dataset_part2\audio_files\jazz\0MOXs5rKf...
# 3  music_dataset_part2\audio_files\jazz\0sGFsWPYy...
# 4  music_dataset_part2\audio_files\jazz\0T38cI9uI...
#
# [5 rows x 317 columns]

# %%
df = pd.concat([df_audios, df_audios2])
print(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.concat([df_audios, df_audios2])
#       2 print(len(df))
#       3 df
#
# NameError: name 'pd' is not defined

# %%
#NOW WE TRY AGAIN WITH THE ADDITIONAL DATA
X = df_audios.drop(["label", "path"], axis=1)
y = df_audios["label"]

#split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

rf = RandomForestClassifier(n_estimators=250, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

#some accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8

# %% [markdown]
# but we still have similar results ...
#
# I forgot to use some preprocessing, maybe this will help :

# %%
def get_numpy_db(df, drop_cols):
    """It removes useless cols regarding parameter drop_cols and it converts df into a numpy array """
    # Preprocess data
    df_x = df.drop(drop_cols, axis=1)
    print("Original DataFrame shape: {}".format(df_x.shape))
    X = df_x.to_numpy()
    return X


def preprocess_db(df, drop_cols, apply_pca=True, explained_var=.9):
    """It applies different preprocessing procedures to the whole dataset in order to 
    scale and transform the original data.
        It returns both the whole dataset and the new query sample after being preprocessed. 
    """
    X = get_numpy_db(df, drop_cols)
    df_dropped = df[drop_cols].reset_index()
    # Scale features
    scaler = StandardScaler()
    X_tr = scaler.fit_transform(X)
    
    # PCA Transformation
    if apply_pca:
        pca = PCA(explained_var)
        X_tr = pca.fit_transform(X_tr)
    #get it back to a dataframe
    df_tr = pd.DataFrame(data=X_tr).reset_index()
    df_tr = pd.concat([df_tr, df_dropped], axis=1)
    return df_tr

# %%
# Parameters
apply_pca=True
explained_var=.90
drop_cols=["label", "path"]

# %%
new_df = preprocess_db(df, drop_cols, apply_pca)
new_df.head()
# Out:
# Original DataFrame shape: (389, 315)
#    index          0         1         2         3         4         5  \
# 0      0  -3.998302 -6.257196 -9.786042 -5.339698  2.306622  7.754866
# 1      1 -10.040385 -1.848138 -5.418832  1.591806 -0.977965  1.333289
# 2      2  -4.757672 -3.746397 -6.012074  2.678091  2.938310 -2.135856
# 3      3  -2.181224 -5.537440 -8.100303  3.419478  1.319312 -1.849413
# 4      4  -2.421254 -7.373567 -0.623400  2.868409 -0.946563 -2.452132
#
#           6         7         8  ...        37        38        39        40  \
# 0 -0.918783 -3.110031  1.778595  ... -0.027456 -1.203986  0.395735  0.531426
# 1 -2.323295  0.397375  0.133910  ... -0.435909  0.915469  0.584292  1.887929
# 2  3.238497 -3.540915 -2.028268  ... -0.084792  1.534239  0.217041 -1.677691
# 3 -3.448708 -2.956501  2.550411  ...  1.240903 -0.366710 -0.015507  0.360024
# 4 -2.088908 -0.798194  5.556367  ... -0.110242 -0.477823 -0.707680  1.783109
#
#          41        42        43  index  label  \
# 0  0.529817  0.786214 -0.640420      0    edm
# 1  0.025197 -0.601872 -0.161961      1    edm
# 2  0.343925  0.071504 -0.899259      2    edm
# 3  0.565218  1.486136 -0.196590      3    edm
# 4  1.112692 -0.310625 -0.966609      4    edm
#
#                                                 path
# 0  music_dataset_part1\audio_files\edm\02RDuI6zo3...
# 1  music_dataset_part1\audio_files\edm\03nmxeZEIZ...
# 2  music_dataset_part1\audio_files\edm\05DQBenN58...
# 3  music_dataset_part1\audio_files\edm\0757375sae...
# 4  music_dataset_part1\audio_files\edm\07uAmmU5pe...
#
# [5 rows x 48 columns]

# %%
#remove these weird columns 'index' used for the concatenation
final_df = new_df.drop(columns=[new_df.columns[0], new_df.columns[45]])
final_df.head()
# Out:
#            0         1         2         3         4         5         6  \
# 0  -3.998302 -6.257196 -9.786042 -5.339698  2.306622  7.754866 -0.918783
# 1 -10.040385 -1.848138 -5.418832  1.591806 -0.977965  1.333289 -2.323295
# 2  -4.757672 -3.746397 -6.012074  2.678091  2.938310 -2.135856  3.238497
# 3  -2.181224 -5.537440 -8.100303  3.419478  1.319312 -1.849413 -3.448708
# 4  -2.421254 -7.373567 -0.623400  2.868409 -0.946563 -2.452132 -2.088908
#
#           7         8         9  ...        36        37        38        39  \
# 0 -3.110031  1.778595 -4.058142  ...  0.362764 -0.027456 -1.203986  0.395735
# 1  0.397375  0.133910 -0.644628  ...  0.729871 -0.435909  0.915469  0.584292
# 2 -3.540915 -2.028268 -1.568277  ...  0.340017 -0.084792  1.534239  0.217041
# 3 -2.956501  2.550411  2.316367  ... -0.086373  1.240903 -0.366710 -0.015507
# 4 -0.798194  5.556367 -0.347246  ...  0.695990 -0.110242 -0.477823 -0.707680
#
#          40        41        42        43  label  \
# 0  0.531426  0.529817  0.786214 -0.640420    edm
# 1  1.887929  0.025197 -0.601872 -0.161961    edm
# 2 -1.677691  0.343925  0.071504 -0.899259    edm
# 3  0.360024  0.565218  1.486136 -0.196590    edm
# 4  1.783109  1.112692 -0.310625 -0.966609    edm
#
#                                                 path
# 0  music_dataset_part1\audio_files\edm\02RDuI6zo3...
# 1  music_dataset_part1\audio_files\edm\03nmxeZEIZ...
# 2  music_dataset_part1\audio_files\edm\05DQBenN58...
# 3  music_dataset_part1\audio_files\edm\0757375sae...
# 4  music_dataset_part1\audio_files\edm\07uAmmU5pe...
#
# [5 rows x 46 columns]

# %%
#NOW WE TRY AGAIN ON THE PREPROCESSED DATA ...
X = final_df.drop(["label", "path"], axis=1)
y = final_df["label"]

#split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

rf = RandomForestClassifier(n_estimators=300, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

#some accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8673469387755102

# %% [markdown]
# We obtain slightly better results, up to 87% accuracy on the prediction
